# %%
# @title Setup for Local Environment

# @title libraries
# Standard library
from pathlib import Path
import os
import re
import json
import datetime
import logging
import warnings

# Data handling
import pandas as pd
import numpy as np

# Excel & HTML parsing
from openpyxl import load_workbook, Workbook
import xlrd       # Older XLS engine
import lxml       # HTML/XML parser
import html5lib   # HTML parser alternative
from bs4 import BeautifulSoup

# Config files
import yaml       # For reading config.yaml

# Image processing
from PIL import Image

# Template rendering for LaTeX
from jinja2 import Environment, FileSystemLoader

# Display
from IPython.display import display

# @title define directories

# Set up local paths
PROJECT_ROOT = Path("/home/ben/Desktop/Projects/media_guide")
DATA_DIR = PROJECT_ROOT / "latex" / "code" / "data"

# Create output directory for processed data
OUT_FOLDER = PROJECT_ROOT / "processed_data"
OUT_FOLDER.mkdir(parents=True, exist_ok=True)

print(f"Project root: {PROJECT_ROOT}")
print(f"Data directory: {DATA_DIR}")
print(f"Output directory: {OUT_FOLDER}")
print(f"Data files found: {list(DATA_DIR.glob('*.xlsx'))}")
# Out:
# Project root: /home/ben/Desktop/Projects/media_guide
# Data directory: /home/ben/Desktop/Projects/media_guide/latex/code/data
# Output directory: /home/ben/Desktop/Projects/media_guide/processed_data
# Data files found: []

# %%
# @title Check Available Data Files

# List all Excel files in the data directory
excel_files = list(DATA_DIR.glob("*.xlsx"))
print(f"Found {len(excel_files)} Excel files:")
for i, file in enumerate(excel_files, 1):
    print(f"{i}. {file.name}")

print(f"\nData directory: {DATA_DIR}")
print(f"Output directory: {OUT_FOLDER}")

# Check if output directory exists and is writable
if OUT_FOLDER.exists():
    print(f"✅ Output directory exists: {OUT_FOLDER}")
else:
    print(f"❌ Output directory does not exist: {OUT_FOLDER}")
    OUT_FOLDER.mkdir(parents=True, exist_ok=True)
    print(f"✅ Created output directory: {OUT_FOLDER}")
# Out:
# Found 0 Excel files:
#
# Data directory: /home/ben/Desktop/Projects/media_guide/latex/code/data
# Output directory: /home/ben/Desktop/Projects/media_guide/processed_data
# ✅ Output directory exists: /home/ben/Desktop/Projects/media_guide/processed_data

# %%
# @title Process Excel Files to Master CSV

def process_excel_to_master_csv():
    """Process all Excel files and create a master CSV with standardized format"""
    
    all_data = []
    
    for excel_file in excel_files:
        print(f"Processing: {excel_file.name}")
        
        try:
            # Load the Excel file
            xls = pd.ExcelFile(excel_file)
            
            for sheet_name in xls.sheet_names:
                print(f"  Sheet: {sheet_name}")
                
                # Read the sheet
                df = pd.read_excel(excel_file, sheet_name=sheet_name, header=None)
                
                # Add metadata columns
                df['SOURCE_FILE'] = excel_file.name
                df['SHEET_NAME'] = sheet_name
                
                # Add to all_data
                all_data.append(df)
                
        except Exception as e:
            print(f"  Error processing {excel_file.name}: {e}")
            continue
    
    if all_data:
        # Combine all dataframes
        master_df = pd.concat(all_data, ignore_index=True)
        
        # Save to CSV
        master_csv_path = OUT_FOLDER / "master_data.csv"
        master_df.to_csv(master_csv_path, index=False)
        
        print(f"\n✅ Created master CSV: {master_csv_path}")
        print(f"Total rows: {len(master_df)}")
        print(f"Columns: {list(master_df.columns)}")
        
        return master_df
    else:
        print("❌ No data processed")
        return pd.DataFrame()

# Uncomment the line below to process your Excel files
# master_df = process_excel_to_master_csv()

# %%
# @title functions

def save_clean_df(df_clean, file_path, sheet_name, out_folder):
    """Save cleaned DataFrame with safe filename."""
    safe_sheet = sheet_name.replace(" ", "_").replace("/", "_")
    safe_file = file_path.stem.replace(" ", "_").replace("/", "_")
    out_path = out_folder / f"{safe_file}_{safe_sheet}_clean.csv"
    df_clean.to_csv(out_path, index=False)
    print(f"Saved cleaned data to {out_path}")

# %%
# @title test file

# File path
file_path = DATA_DIR / "SCIAC Top 10 4.1.25.xlsx"

# Inspect sheet names
xls = pd.ExcelFile(file_path)
print("Sheet names:", xls.sheet_names)

# Load the first sheet (index 0)
sheet_name = xls.sheet_names[0]
df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)

# Show first 20 rows so we can decide cleaning steps
df.head(5)

#save_clean_df(df_clean, file_path, sheet_name, OUT_FOLDER)

# %% [markdown]
# https://cmsathletics.org/services/schedule_txt.ashx?schedule=365
# https://cmsathletics.org/services/schedule_txt.ashx?schedule=382
# https://cmsathletics.org/services/schedule_txt.ashx?schedule=381
# https://cmsathletics.org/services/schedule_txt.ashx?schedule=364

# %%
# @title Merge

SRC_DIR = DATA_DIR  # Use the DATA_DIR we defined earlier
OUT_PATH = OUT_FOLDER / "merged.xlsx"
OUT_PATH.parent.mkdir(parents=True, exist_ok=True)

wb_out = Workbook()
wb_out.remove(wb_out.active)  # drop default empty sheet

for f in SRC_DIR.glob("*.xlsx"):
    try:
        wb_in = load_workbook(f, data_only=True)
    except Exception as e:
        print(f"Skipping {f.name}: {e}")
        continue

    for ws in wb_in.worksheets:
        # make a unique name (Excel caps at 31 chars)
        out_name = (f"{f.stem}_{ws.title}")[:31]
        out_ws = wb_out.create_sheet(out_name)
        for row in ws.iter_rows(values_only=True):
            out_ws.append(row)

    wb_in.close()

wb_out.save(OUT_PATH)
print(f"✅ Saved merged workbook to {OUT_PATH}")
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/workbook/child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# ✅ Saved merged workbook to /content/drive/My Drive/cms_media_guide/processed_data/merged.xlsx

# %%
# Check if the CSV file exists, if not, we'll need to create it from the Excel files
csv_file = OUT_FOLDER / "master_CMS - times-2.csv"
if csv_file.exists():
    times_df = pd.read_csv(csv_file)
    print(f"Loaded existing CSV file: {csv_file}")
else:
    print(f"CSV file not found: {csv_file}")
    print("You may need to create this file from your Excel data first.")
    # Create an empty dataframe for now
    times_df = pd.DataFrame()

times_df.head()
# Out:
#        SHEET     SEX     EVENT   TIME              NAME  YEAR TEAM  RANK SITE  \
# 0  CMS at PP  Athena  50 FREE   23.29  Jocelyn Crawford  2018  NaN   NaN  NaN
# 1  CMS at PP  Athena  50 FREE   23.64  Jocelyn Crawford  2017  NaN   NaN  NaN
# 2  CMS at PP  Athena  50 FREE   23.66     Madeleine Kan  2024  NaN   NaN  NaN
# 3  CMS at PP  Athena  50 FREE   23.89     Ava Sealander  2021  NaN   NaN  NaN
# 4  CMS at PP  Athena  50 FREE   24.04     Ava Sealander  2019  NaN   NaN  NaN
#
#   MEET CONTEXT
# 0  NaN     NaN
# 1  NaN     NaN
# 2  NaN     NaN
# 3  NaN     NaN
# 4  NaN     NaN

# %%
# Strip whitespace from column names just in case
times_df.columns = times_df.columns.str.strip()

# Columns to ignore
ignore_cols = {"SHEET", "SEX", "EVENT"}

# Create a mask of non-null columns (excluding ignored ones)
patterns = times_df.drop(columns=ignore_cols, errors="ignore").notna()

# Turn each row’s pattern into a tuple of filled-in column names
filled_sets = patterns.apply(
    lambda row: tuple(col for col, filled in row.items() if filled),
    axis=1
)

# Get unique combinations
unique_combinations = filled_sets.unique()

print("Unique combinations of filled columns (ignoring SHEET and SEX):")
for combo in unique_combinations:
    print(combo)
# Out:
# Unique combinations of filled columns (ignoring SHEET and SEX):
# ('TIME', 'NAME', 'YEAR')
# ('TIME', 'NAME', 'YEAR', 'TEAM')
# ('TIME', 'NAME', 'YEAR', 'TEAM', 'RANK')
# ('TIME', 'YEAR', 'TEAM', 'RANK')
# ('NAME', 'YEAR')
# ('TIME', 'NAME', 'YEAR', 'SITE')
# ('TIME', 'NAME', 'YEAR', 'SITE', 'MEET', 'CONTEXT')
# ('TIME', 'NAME', 'YEAR', 'TEAM', 'MEET')

# %%
latex_labels = {
    "TIME": "Time",
    "NAME": "Name",
    "YEAR": "Year",
    "TEAM": "Team",
    "RANK": "Rank",
    "SITE": "Site",
    "MEET": "Meet",
    "CONTEXT": "Context"
}


# Assuming `unique_combinations` already exists from previous step

macros = []
for combo in unique_combinations:
    # Macro name based on joined column names
    macro_name = "eventtable" + "".join(col.capitalize() for col in combo)

    # Column format string: l for text, r for numbers (here: YEAR and RANK)
    col_format = " ".join("r" if col in {"YEAR", "RANK"} else "l" for col in combo)

    # Table headers
    headers = " & ".join(f"\\textbf{{{latex_labels[col]}}}" for col in combo)

    macro = f"""
% Auto-generated macro
\\newcommand{{\\{macro_name}}}[2]{{
\\begin{{table}}[h!]
\\centering
\\caption*{{#1}}
\\vspace{{-0.25cm}}
\\begin{{tabular}}{{{col_format}}}
\\hline
{headers} \\\\
\\hline
#2
\\hline
\\end{{tabular}}
\\end{{table}}
}}
"""
    macros.append(macro)

for macro in macros:
    print(macro)
# Out:
# % Auto-generated macro
# \newcommand{\eventtableTimeNameYear}[2]{
# \begin{table}[h!]
# \centering
# \caption*{#1}
# \vspace{-0.25cm}
# \begin{tabular}{l l r}
# \hline
# \textbf{Time} & \textbf{Name} & \textbf{Year} \\
# \hline
# #2
# \hline
# \end{tabular}
# \end{table}
# }
#
#
# % Auto-generated macro
# \newcommand{\eventtableTimeNameYearTeam}[2]{
# \begin{table}[h!]
# \centering
# \caption*{#1}
# \vspace{-0.25cm}
# \begin{tabular}{l l r l}
# \hline
# \textbf{Time} & \textbf{Name} & \textbf{Year} & \textbf{Team} \\
# \hline
# #2
# \hline
# \end{tabular}
# \end{table}
# }
#
#
# % Auto-generated macro
# \newcommand{\eventtableTimeNameYearTeamRank}[2]{
# \begin{table}[h!]
# \centering
# \caption*{#1}
# \vspace{-0.25cm}
# \begin{tabular}{l l r l r}
# \hline
# \textbf{Time} & \textbf{Name} & \textbf{Year} & \textbf{Team} & \textbf{Rank} \\
# \hline
# #2
# \hline
# \end{tabular}
# \end{table}
# }
#
#
# % Auto-generated macro
# \newcommand{\eventtableTimeYearTeamRank}[2]{
# \begin{table}[h!]
# \centering
# \caption*{#1}
# \vspace{-0.25cm}
# \begin{tabular}{l r l r}
# \hline
# \textbf{Time} & \textbf{Year} & \textbf{Team} & \textbf{Rank} \\
# \hline
# #2
# \hline
# \end{tabular}
# \end{table}
# }
#
#
# % Auto-generated macro
# \newcommand{\eventtableNameYear}[2]{
# \begin{table}[h!]
# \centering
# \caption*{#1}
# \vspace{-0.25cm}
# \begin{tabular}{l r}
# \hline
# \textbf{Name} & \textbf{Year} \\
# \hline
# #2
# \hline
# \end{tabular}
# \end{table}
# }
#
#
# % Auto-generated macro
# \newcommand{\eventtableTimeNameYearSite}[2]{
# \begin{table}[h!]
# \centering
# \caption*{#1}
# \vspace{-0.25cm}
# \begin{tabular}{l l r l}
# \hline
# \textbf{Time} & \textbf{Name} & \textbf{Year} & \textbf{Site} \\
# \hline
# #2
# \hline
# \end{tabular}
# \end{table}
# }
#
#
# % Auto-generated macro
# \newcommand{\eventtableTimeNameYearSiteMeetContext}[2]{
# \begin{table}[h!]
# \centering
# \caption*{#1}
# \vspace{-0.25cm}
# \begin{tabular}{l l r l l l}
# \hline
# \textbf{Time} & \textbf{Name} & \textbf{Year} & \textbf{Site} & \textbf{Meet} & \textbf{Context} \\
# \hline
# #2
# \hline
# \end{tabular}
# \end{table}
# }
#
#
# % Auto-generated macro
# \newcommand{\eventtableTimeNameYearTeamMeet}[2]{
# \begin{table}[h!]
# \centering
# \caption*{#1}
# \vspace{-0.25cm}
# \begin{tabular}{l l r l l}
# \hline
# \textbf{Time} & \textbf{Name} & \textbf{Year} & \textbf{Team} & \textbf{Meet} \\
# \hline
# #2
# \hline
# \end{tabular}
# \end{table}
# }

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# Strip whitespace from column names just in case
times_df.columns = times_df.columns.str.strip()

# Prepare unique values
sheets = sorted(times_df["SHEET"].dropna().unique())
sexes = sorted(times_df["SEX"].dropna().unique())

# Dropdowns
sheet_dd = widgets.Dropdown(options=sheets, description="Sheet:")
sex_dd = widgets.Dropdown(options=sexes, description="Sex:")

# Grid controls
rows_dd = widgets.IntSlider(value=3, min=1, max=5, description="Rows:")
cols_dd = widgets.IntSlider(value=3, min=1, max=5, description="Cols:")

# Button
print_btn = widgets.Button(description="Print All Events")

# Sorting key function for EVENT_CLEAN
stroke_order = ["FREE", "BACK", "BREAST", "FLY", "IM"]

def event_sort_key(event):
    event_upper = event.upper()

    # Diving events
    if "METER" in event_upper:
        stroke_index = 999
        match = re.search(r'\d+', event_upper)
        distance = int(match.group()) if match else 0
        dives_match = re.search(r'\((\d+)\s*DIVES\)', event_upper)
        dives = int(dives_match.group(1)) if dives_match else 0
        return (stroke_index, distance, dives, event_upper)

    # Relay/Splits
    relay_flag = 1 if "RELAY" in event_upper or "SPL" in event_upper else 0

    # Individual strokes
    stroke_index = 0
    for i, stroke in enumerate(stroke_order):
        if stroke in event_upper:
            stroke_index = i
            break

    # Numeric distance
    match = re.search(r'\d+', event_upper)
    distance = int(match.group()) if match else 0

    return (relay_flag, stroke_index, distance, event_upper)

# Function to print tables
def print_all_events(_):
    clear_output(wait=True)
    display(sheet_dd, sex_dd, rows_dd, cols_dd, print_btn)

    sheet = sheet_dd.value
    sex = sex_dd.value
    nrows, ncols = rows_dd.value, cols_dd.value

    # Filter dataframe
    df_filtered = times_df[(times_df["SHEET"] == sheet) & (times_df["SEX"] == sex)]
    events = sorted(df_filtered["EVENT_CLEAN"].dropna().unique(), key=event_sort_key)

    if not events:
        print("⚠️ No events found for this sheet and sex.")
        return

    out = ["\\begin{center}"]

    for i, event in enumerate(events):
        df_event = df_filtered[df_filtered["EVENT_CLEAN"] == event]
        cols_used = [col for col in df_event.columns if col not in {"SHEET","SEX","EVENT","EVENT_CLEAN"} and df_event[col].notna().any()]
        macro_name = "eventtable" + "".join(col.capitalize() for col in cols_used)

        # Build table rows
        rows = []
        for _, row in df_event.iterrows():
            vals = [str(row[c]) for c in cols_used]
            rows.append(" & ".join(vals) + " \\\\")
        rows_block = "\n".join(rows)
        latex_cmd = f"\\{macro_name}{{{event}}}{{%\n{rows_block}\n}}"

        # Wrap in minipage
        width = 1 / ncols
        out.append(f"\\begin{{minipage}}{{{width:.3f}\\linewidth}}\\centering\n{latex_cmd}\n\\end{{minipage}}")

        # Row break every ncols
        if (i+1) % ncols == 0:
            out.append("\\par\\bigskip")


    print("\n".join(out))

# Connect button
print_btn.on_click(print_all_events)

# Display UI
display(sheet_dd, sex_dd, rows_dd, cols_dd, print_btn)

# %%
# Strip whitespace from column names just in case
times_df.columns = times_df.columns.str.strip()

output = []

for sheet in sorted(times_df["SHEET"].dropna().unique()):

    output.append(f"\n\\section{{{sheet}}}")

    sexes = sorted(times_df.loc[times_df["SHEET"] == sheet, "SEX"].dropna().unique())
    for sex in sexes:
        output.append(f"\\subsection{{{sex}}}")


# Print LaTeX skeleton
print("\n".join(output))

# %%
import re

# Clean event names
times_df["EVENT_clean"] = times_df["EVENT"].astype(str).str.strip()

# Normalize "3-M" → "3-METER" and remove double spaces
times_df["EVENT_clean"] = times_df["EVENT_clean"].str.replace(r'\b3-M\b', '3-METER', regex=True)
times_df["EVENT_clean"] = times_df["EVENT_clean"].str.replace(r'\s+', ' ', regex=True)

unique_events = times_df["EVENT_clean"].dropna().unique()

# Stroke order for individuals
stroke_order = ["FREE", "BACK", "BREAST", "FLY", "IM"]

def event_sort_key(event):
    event_upper = event.upper()

    # Check if diving
    if "METER" in event_upper:
        stroke_index = 999  # Diving goes last
        # Extract numeric meter for secondary sort
        match = re.search(r'\d+', event_upper)
        distance = int(match.group()) if match else 0
        # Check for "(X DIVES)" and use number for tertiary sort
        dives_match = re.search(r'\((\d+)\s*DIVES\)', event_upper)
        dives = int(dives_match.group(1)) if dives_match else 0
        return (stroke_index, distance, dives, event_upper)

    # Check if relay/split
    relay_flag = 1 if "RELAY" in event_upper or "SPL" in event_upper else 0

    # Determine stroke index for individual events
    stroke_index = 0
    for i, stroke in enumerate(stroke_order):
        if stroke in event_upper:
            stroke_index = i
            break

    # Extract numeric distance
    match = re.search(r'\d+', event_upper)
    distance = int(match.group()) if match else 0

    return (relay_flag, stroke_index, distance, event_upper)

# Sort unique events
sorted_events = sorted(set(unique_events), key=event_sort_key)

# Print result
for e in sorted_events:
    print(e)

# %%
import pandas as pd
import re

# Assuming times_df is already loaded
# times_df = pd.read_csv(...)

# 1. Strip whitespace from all string columns
str_cols = times_df.select_dtypes(include='object').columns
times_df[str_cols] = times_df[str_cols].apply(lambda x: x.str.strip())

# 2. Normalize column names (optional)
times_df.columns = [c.strip().upper() for c in times_df.columns]

# 3. Normalize events
times_df["EVENT"] = times_df["EVENT"].astype(str).str.strip()
times_df["EVENT"] = times_df["EVENT"].str.replace(r'\s+', ' ', regex=True)       # remove double spaces
times_df["EVENT"] = times_df["EVENT"].str.replace(r'\b3-M\b', '3-METER', regex=True)  # fix 3-M

# 4. Add clean event column for sorting
times_df["EVENT_CLEAN"] = times_df["EVENT"]

# 5. Define sorting key (same as before)
stroke_order = ["FREE", "BACK", "BREAST", "FLY", "IM"]

def event_sort_key(event):
    event_upper = event.upper()

    # Diving events
    if "METER" in event_upper:
        stroke_index = 999
        match = re.search(r'\d+', event_upper)
        distance = int(match.group()) if match else 0
        dives_match = re.search(r'\((\d+)\s*DIVES\)', event_upper)
        dives = int(dives_match.group(1)) if dives_match else 0
        return (stroke_index, distance, dives, event_upper)

    # Relay/Splits
    relay_flag = 1 if "RELAY" in event_upper or "SPL" in event_upper else 0

    # Individual strokes
    stroke_index = 0
    for i, stroke in enumerate(stroke_order):
        if stroke in event_upper:
            stroke_index = i
            break

    match = re.search(r'\d+', event_upper)
    distance = int(match.group()) if match else 0

    return (relay_flag, stroke_index, distance, event_upper)

# 6. Sort times_df by EVENT_CLEAN
times_df = times_df.sort_values("EVENT_CLEAN", key=lambda x: x.map(event_sort_key))

# 7. Reset index
times_df = times_df.reset_index(drop=True)

# %%
times_df.to_csv(OUT_FOLDER / "times_df.csv", index=False)

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import math

# Dropdowns
sheets = sorted(times_df["SHEET"].dropna().unique())
sexes = sorted(times_df["SEX"].dropna().unique())

sheet_dd = widgets.Dropdown(options=sheets, description="Sheet:")
sex_dd = widgets.Dropdown(options=sexes, description="Sex:")
rows_dd = widgets.IntSlider(value=3, min=1, max=5, description="Rows:")
cols_dd = widgets.IntSlider(value=3, min=1, max=5, description="Cols:")

print_btn = widgets.Button(description="Print Tables")

# Function to generate LaTeX tables in subtable grid
def print_event_grid(_):
    clear_output(wait=True)
    display(sheet_dd, sex_dd, rows_dd, cols_dd, print_btn)

    sheet = sheet_dd.value
    sex = sex_dd.value
    nrows, ncols = rows_dd.value, cols_dd.value

    df_filtered = times_df[(times_df["SHEET"] == sheet) & (times_df["SEX"] == sex)]
    if df_filtered.empty:
        print("⚠️ No events for this selection.")
        return

    # Sort unique events
    events = sorted(df_filtered["EVENT_CLEAN"].dropna().unique(), key=event_sort_key)

    # Generate LaTeX for each event table
    table_codes = []
    for event in events:
        df_event = df_filtered[df_filtered["EVENT_CLEAN"] == event]
        cols_used = [col for col in df_event.columns if col not in {"SHEET","SEX","EVENT","EVENT_CLEAN"} and df_event[col].notna().any()]
        macro_name = "eventtable" + "".join(col.capitalize() for col in cols_used)

        rows = []
        for _, row in df_event.iterrows():
            vals = [str(row[c]) for c in cols_used]
            rows.append(" & ".join(vals) + " \\\\")
        rows_block = "\n".join(rows)
        latex_cmd = f"\\{macro_name}{{{event}}}{{%\n{rows_block}\n}}"
        table_codes.append(latex_cmd)

    # Wrap tables in subtable grid
    out = []
    tables_per_page = nrows * ncols
    for page_start in range(0, len(table_codes), tables_per_page):
        page_tables = table_codes[page_start:page_start + tables_per_page]
        out.append("\\begin{table}[h!]\n\\centering")
        for i, t in enumerate(page_tables):
            out.append(f"\\begin{{subtable}}[t]{{{1/ncols:.3f}\\linewidth}}\\centering\n{t}\n\\end{{subtable}}")
            if (i + 1) % ncols != 0:
                out.append("%")  # prevents unwanted space between subtables
            else:
                out.append("\\\\[1em]")  # new row
        out.append(f"\\caption{{Events for Sheet {sheet}, Sex {sex}}}")
        out.append("\\end{table}\n\n")

    print("\n".join(out))

print_btn.on_click(print_event_grid)
display(sheet_dd, sex_dd, rows_dd, cols_dd, print_btn)
# Out:
# Dropdown(description='Sheet:', options=('CMS All Time Top 10', 'CMS Axelrood Pool Records', 'CMS Frosh Swimmin…
# Dropdown(description='Sex:', options=('Athena', 'Men', 'Stag', 'Stags', 'Women'), value='Athena')
# IntSlider(value=3, description='Rows:', max=5, min=1)
# IntSlider(value=3, description='Cols:', max=5, min=1)
# Button(description='Print Tables', style=ButtonStyle())
# \begin{table}[h!]
# \centering
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{50 FREE}{%
# 23.29 & Jocelyn Crawford & 2019 \\
# 23.31 & Ava Sealander & 2022 \\
# 23.49 & Kelly Ngo & 2016 \\
# 23.77 & Suzia Starzyk & 2020 \\
# 23.71 & Helen Liu & 2014 \\
# 23.75 & Annika Sharma & 2024 \\
# 23.76 & Michele Kee & 2014 \\
# 23.87 & Katie Bilotti & 2010 \\
# 23.77 & Natalia Orbach-M & 2020 \\
# 23.39 & Madeleine Kan & 2025 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{100 FREE}{%
# 51.05 & Kelly Ngo & 2016 \\
# 51.24 & Jocelyn Crawford & 2017 \\
# 51.41 & Michele Kee & 2014 \\
# 51.47 & Madeleine Kan & 2025 \\
# 51.56 & Natalia Orbach-M & 2020 \\
# 51.72 & Annika Sharma & 2024 \\
# 51.88 & Riley Hoffman & 2019 \\
# 52.05 & Emma Jones & 2009 \\
# 52.05 & Jenni Rinker & 2011 \\
# 51.56 & Ava Sealander & 2022 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{200 FREE}{%
# 1:50.30 & Ella Blake & 2022 \\
# 1:51.75 & Sun Young Byun & 2024 \\
# 1:51.89 & Sarah Heine & 2006 \\
# 1:52.40 & Katy Shaw & 2023 \\
# 1:52.55 & Natalia Orbach-M & 2022 \\
# 1:52.57 & Riley Hoffman & 2019 \\
# 1:52.67 & Augusta Lewis & 2022 \\
# 1:52.80 & Leila El Masri & 2022 \\
# 1:52.83 & Christina Campbell & 2020 \\
# 1:52.89 & Jamee Mitchum & 2022 \\
# }
# \end{subtable}
# \\[1em]
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{500 FREE}{%
# 4:57.37 & Katy Shaw & 2024 \\
# 4:58.11 & Corley Smith & 2024 \\
# 4:57.37 & Mia Syme & 2018 \\
# 5:01.99 & Gracey Hiebert & 2020 \\
# 5:01.60 & Avalon Sanders & 2025 \\
# 5:01.17 & Lizzie Carrade & 2017 \\
# 5:00.47 & Carliann Brashier & 2009 \\
# 5:00.06 & Whitney Dawson & 2009 \\
# 4:59.78 & Leila El Masri & 2022 \\
# 4:59.22 & Ella Blake & 2022 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{1000 FREE}{%
# 10:14.33 & Whitney Dawson & 2009 \\
# 10:15.40 & Mia Syme & 2019 \\
# 10:22.59 & Carliann Brashier & 2009 \\
# 10:22.84 & Lizzie Carrade & 2017 \\
# 10:23.10 & Corley Smith & 2024 \\
# 10:24.14 & Molly Loftus & 2014 \\
# 10:26.34 & Gracey Hiebert & 2022 \\
# 10:26.88 & Katy Shaw & 2024 \\
# 10:26.89 & Ella Blake & 2022 \\
# 10:24.82 & Lauren Williams & 1999 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{1650 FREE}{%
# 17:13.58 & Molly Loftus & 2014 \\
# 17:12.74 & Corley Smith & 2024 \\
# 17:12.46 & Ella Blake & 2022 \\
# 17:12.18 & Gracey Hiebert & 2020 \\
# 17:09.26 & Lizzie Carrade & 2017 \\
# 17:06.78 & Carliann Brashier & 2009 \\
# 17:03.35 & Katy Shaw & 2025 \\
# 17:03.21 & Mia Syme & 2019 \\
# 16:58.48 & Whitney Dawson & 2009 \\
# 17:09.09 & Lauren Williams & 1998 \\
# }
# \end{subtable}
# \\[1em]
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{100 BACK}{%
# 55.66 & Kelly Ngo & 2015 \\
# 55.67 & Jocelyn Crawford & 2017 \\
# 55.91 & Jamee Mitchum & 2022 \\
# 56.11 & Katie Bilotti & 2010 \\
# 56.74 & Tessa Dover & 2010 \\
# 56.77 & Annika Sharma & 2024 \\
# 56.83 & Sammy Ennis & 2022 \\
# 57.18 & Sun Young Byun & 2023 \\
# 57.36 & Annika Jessen & 2014 \\
# 57.47 & Elsa Cheng & 2011 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{200 BACK}{%
# 2:04.62 & Annika Sharma & 2024 \\
# 2:05.10 & Natalie Larsen & 2019 \\
# 2:05.29 & Caitlin Kuhlmann & 2025 \\
# 2:05.39 & Nika Makhervaks & 2025 \\
# 2:05.56 & Jenni Rinker & 2011 \\
# 2:03.85 & Christina Campbell & 2020 \\
# 2:03.92 & Sammy Ennis & 2022 \\
# 1:59.91 & Jamee Mitchum & 2022 \\
# 2:02.10 & Tessa Dover & 2010 \\
# 2:03.73 & Ivy Chen & 2017 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{100 BREAST}{%
# 1:03.28 & Augusta Lewis & 2022 \\
# 1:04.19 & Rachel Wander & 2020 \\
# 1:04.16 & Bryn Edwards & 2017 \\
# 1:03.91 & Mackenzie Mayfield & 2023 \\
# 1:03.51 & C Bacon-Brenes & 2017 \\
# 1:04.31 & Milan Manfredi & 2024 \\
# 1:04.66 & Zuzia Starzyk & 2020 \\
# 1:04.65 & Kelly Ngo & 2014 \\
# 1:04.36 & Kelly Prawira & 2025 \\
# 1:01.84 & Annie Perizzolo & 2010 \\
# }
# \end{subtable}
# \\[1em]
# \caption{Events for Sheet CMS All Time Top 10, Sex Athena}
# \end{table}
#
#
# \begin{table}[h!]
# \centering
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{200 BREAST}{%
# 2:22.34 & Rachel Wander & 2022 \\
# 2:21.77 & Mackenzie Mayfield & 2023 \\
# 2:21.17 & Suzy Nicoletti & 2002 \\
# 2:21.62 & Allyson Yao & 2024 \\
# 2:14.83 & Annie Perizzolo & 2010 \\
# 2:15.62 & Augusta Lewis & 2022 \\
# 2:18.99 & Kelly Prawira & 2023 \\
# 2:19.06 & C Bacon-Brenes & 2017 \\
# 2:19.78 & Emily McKinnon & 2015 \\
# 2:20.01 & Kelly Ngo & 2014 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{100 FLY}{%
# 54.78 & Sun Young Byun & 2025 \\
# 54.76 & Katelyn Dang & 2022 \\
# 54.92 & Ava Sealander & 2022 \\
# 55.01 & Mackenzie Mayfield & 2025 \\
# 54.93 & Katie Bilotti & 2010 \\
# 56.42 & Lorea Gwo & 2015 \\
# 56.04 & Annika Jessen & 2014 \\
# 55.74 & Michele Kee & 2011 \\
# 55.13 & Madeleine Kan & 2025 \\
# 56.47 & Stephanie Doi & 2017 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{200 FLY}{%
# 2:02.58 & Katelyn Dang & 2022 \\
# 2:03.22 & Sun Young Byun & 2024 \\
# 2:03.80 & Michele Kee & 2012 \\
# 2:04.05 & Ava Sealander & 2020 \\
# 2:04.42 & Annie Johnson & 2023 \\
# 2:04.81 & Annika Jessen & 2014 \\
# 2:06.40 & Arisa Cowe & 2020 \\
# 2:07.12 & Maya Kale & 2013 \\
# 2:01.84 & Augusta Lewis & 2023 \\
# 2:01.30 & Mackenzie Mayfield & 2025 \\
# }
# \end{subtable}
# \\[1em]
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{200 IM}{%
# 2:00.69 & Augusta Lewis & 2023 \\
# 2:02.63 & Mackenzie Mayfield & 2025 \\
# 2:03.59 & Jamee Mitchum & 2022 \\
# 2:03.79 & Michele Kee & 2012 \\
# 2:05.07 & Allyson Yao & 2024 \\
# 2:05.41 & Stephanie Doi & 2016 \\
# 2:05.93 & Sun Young Byun & 2024 \\
# 2:07.12 & Suzy Nicoletti & 2002 \\
# 2:07.14 & Natalie Larsen & 2020 \\
# 2:07.52 & Molly Beetner & 2025 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{400 IM}{%
# 4:15.73 & Augusta Lewis & 2023 \\
# 4:25.84 & Allyson Yao & 2024 \\
# 4:26.93 & Mackenzie Mayfield & 2025 \\
# 4:27.18 & Lisal Smith & 2004 \\
# 4:30.77 & Ivy Chen & 2017 \\
# 4:31.11 & Revere Schmidt & 2024 \\
# 4:31.96 & Natalie Larsen & 2019 \\
# 4:32.00 & Allison Nguyen & 2024 \\
# 4:32.45 & Jordan Stewart & 2009 \\
# 4:32.57 & Lauren Williams & 2002 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{50 BRST - RELAY Spl.}{%
# 29.26 & Zuzia Starzyk & 2020 \\
# 28.33 & Annie Perizzolo & 2010 \\
# 28.70 & Mackenzie Mayfield & 2024 \\
# 28.75 & Milan Manfredi & 2024 \\
# 29.05 & C Bacon-Brenes & 2017 \\
# 29.06 & Maggie Wang & 1997 \\
# 29.09 & Rachel Wander & 2020 \\
# 29.09 & Augusta Lewis & 2023 \\
# 29.21 & Kelly Prawira & 2025 \\
# 29.24 & Stephanie Doi & 2015 \\
# }
# \end{subtable}
# \\[1em]
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{50 FREE - RELAY Spl.}{%
# 23.28 & Annette Chang & 2024 \\
# 23.31 & Kelly Ngo & 2014 \\
# 23.27 & Katie Bilotti & 2010 \\
# 23.21 & Mackenzie Mayfield & 2024 \\
# 22.95 & Jocelyn Crawford & 2017 \\
# 22.93 & Natalia Orbach-M & 2018 \\
# 22.92 & Helen Liu & 2014 \\
# 22.69 & Ava Sealander & 2022 \\
# 22.60 & Madeleine Kan & 2025 \\
# 23.33 & Michele Kee & 2012 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{100 BRST - RELAY Spl.}{%
# 1:01.10 & Annie Perizzolo & 2010 \\
# 1:04.26 & Maddy Gebhard & 2013 \\
# 1:02.88 & Augusta Lewis & 2022 \\
# 1:02.89 & Mackenzie Mayfield & 2023 \\
# 1:03.67 & C Bacon-Brenes & 2017 \\
# 1:03.73 & Kelly Prawira & 2025 \\
# 1:04.10 & Bryn Edwards & 2018 \\
# 1:04.35 & Kelly Ngo & 2014 \\
# 1:04.24 & Zuzia Starzyk & 2020 \\
# 1:04.16 & Rachel Wander & 2022 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{100 FREE - RELAY Spl.}{%
# 49.87 & Madeleine Kan & 2025 \\
# 51.45 & Ava Sealander & 2022 \\
# 51.37 & Sarah Heine & 2006 \\
# 51.29 & Helen Liu & 2014 \\
# 51.28 & Riley Hoffman & 2018 \\
# 51.27 & Emma Jones & 2010 \\
# 50.65 & Natalia Orbach-M & 2019 \\
# 50.67 & Michele Kee & 2012 \\
# 51.19 & LillyBelle Deer & 2015 \\
# 50.92 & Kelly Ngo & 2017 \\
# }
# \end{subtable}
# \\[1em]
# \caption{Events for Sheet CMS All Time Top 10, Sex Athena}
# \end{table}
#
#
# \begin{table}[h!]
# \centering
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{200 FREE - RELAY Spl.}{%
# 1:52.78 & Jordan Stewart & 2009 \\
# 1:52.53 & Michele Kee & 2012 \\
# 1:52.50 & Allison Nguyen & 2025 \\
# 1:51.95 & LillyBelle Deer & 2015 \\
# 1:50.91 & Sarah Heine & 2006 \\
# 1:51.64 & Christina Campbell & 2020 \\
# 1:50.98 & Ella Blake & 2022 \\
# 1:51.56 & Riley Hoffman & 2018 \\
# 1:51.39 & Augusta Lewis & 2023 \\
# 1:51.41 & Katy Shaw & 2023 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYearSite{200 FREE RELAY}{%
# 1:34.85 & Mayfield (23.99), Sharma (23.90), Rudolph (24.00), Kan (22.96) & 2025 & SCIAC \\
# 1:34.80 & Kee (23.85), Bilotti (23.88), Jones (23.78), Liu (23.29) & 2012 & NCAA \\
# 1:34.78 & Ngo (23.50), Deer (23.86), Doi (23.64), Gwo (23.78) & 2015 & NCAA \\
# 1:34.57 & Sharma (24.20), Mayfield (23.82), Chang (23.79), Kan (22.76) & 2025 & PP Dual \\
# 1:34.53 & Crawford (23.49), Orbach-M (23.10), Dickinson (24.02), Hoffman (23.92) & 2018 & SCIAC \\
# 1:34.52 & Crawford (23.84), Hoffman (23.80), Sealander (23.61), Orbach-M (23.27) & 2019 & SCIAC \\
# 1:34.07 & Sealander (23.89), Starzyk (23.45), Tran (23.77), Orbach-M (22.96) & 2020 & SCIAC \\
# 1:33.95 & Sharma (24.02), Mayfield (23.21), Kan (23.15), Chang (23.57) & 2024 & SCIAC \\
# 1:33.94 & Kee (23.88), Ngo (23.31), Chan (23.76), Liu (22.99) & 2014 & SCIAC \\
# 1:33.87 & Crawford (23.40), Stacy (23.96), Hoffman (23.58), Orbach-M (22.93) & 2018 & NCAA \\
# 1:34.85 & Mayfield (24.24), Chang (23.75), Byun (23.91), Kan (22.95) & 2025 & NCAA \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYearSite{200 MEDLEY RELAY}{%
# 1:43.83 & Mitchum (26.54), Starzyk (29.26), Lewis S (24.80), Orbach-M (23.23) & 2020 & SCIAC \\
# 1:43.70 & Mitchum (26.49), Mayfield (28.96), Byun (24.74), Sharma (23.51) & 2023 & SCIAC \\
# 1:43.60 & Cheng (26.75), Perizzolo (28.35), Bilotti (24.78), Rinker (23.72) & 2010 & SCIAC \\
# 1:43.56 & Cheng (26.57), Jones (29.57), Bilotti (24.34), Liu (23.08) & 2011 & NCAA \\
# 1:43.37 & Sharma (26.27), Mayfield (29.43), Byun (25.07), Kan (22.60) & 2025 & PP dual \\
# 1:43.21 & Chang (26.73), Manfredi (29.11), Mayfield (24.44), Kan (22.93) & 2025 & NCAA \\
# 1:43.26 & Mitchum, Wander, Dang (24.58), Sealander (22.70) & 2022 & SCIAC \\
# 1:43.09 & Cheng (26.58), Perizzolo (28.33), Bilotti (24.55), Jones (23.63) & 2010 & NCAA \\
# 1:42.91 & Sharma (26.20), Mayfield (28.70), Byun (24.73), Chang (23.28) & 2024 & SCIAC \\
# 1:42.21 & Sharma (25.98), Manfredi (28.84), Mayfield (24.34), Kan (23.05) & 2025 & SCIAC \\
# }
# \end{subtable}
# \\[1em]
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYearSite{400 FREE RELAY}{%
# 3:27.22 & Sharma (51.82), Mayfield (52.07), Kan (51.17), Chang (52.16) & 2024 & NCAA \\
# 3:27.43 & Rinker (52.05), Liu (52.13), Jones (52.12), Kee (51.13) & 2011 & SCIAC \\
# 3:27.47 & Crawford (52.32), Umemoto (52.83), Hoffman (51.28), Orbach-M (51.04) & 2018 & NCAA \\
# 3:26.55 & Blake (52.17), Sealander (51.45), Dang (51.94), Orbach-M (50.99) & 2022 & NCAA \\
# 3:27.55 & Sharma (52.54), Mayfield (52.50), Chang (52.64), Kan (49.87) & 2025 & PP dual \\
# 3:27.56 & Ngo (51.25), Doi (52.06), Flaten (52.96), Deer (51.29) & 2015 & NCAA \\
# 3:26.32 & Kee (51.41), Liu (51.29), Deer (52.06), Ngo (51.56) & 2014 & NCAA \\
# 3:27.18 & Tran (52.14), Umemoto (51.96), Lewis (52.37), Orbach-M (50.71) & 2020 & SCIAC \\
# 3:27.75 & Hoffman (52.17), Tran (52.24), Stacy (52.37), Orbach-M (50.97) & 2019 & NCAA \\
# 3:27.95 & Liu (52.60), Jones (51.84), Bilotti (52.72), Kee (50.79) & 2012 & NCAA \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYearSite{400 MEDLEY RELAY}{%
# 3:44.60 & Dover (57.25), Perizzolo (1:01.10), Bilotti (54.98), Jones (51.27) & 2010 & NCAA \\
# 3:45.55 & Ennis (57.27), Prawira (1:03.96), Mayfield (54.29), Kan (50.03) & 2025 & NCAA \\
# 3:45.87 & Mitchum (57.14), Lewis (1:02.98), Sealander (55.05), Orbach-M (50.70) & 2020 & SCIAC \\
# 3:46.02 & Mitchum (56.18), Lewis (1:02.88), Sealander (55.77), Orbach-M (51.19) & 2022 & NCAA \\
# 3:46.24 & Rinker (57.65), Perizzolo (1:01.40), Bilotti (55.08), Jones (52.11) & 2010 & SCIAC \\
# 3:47.73 & Rinker (57.56), Perizzolo (1:02.25), Bilotti (54.91), Jones (53.01) & 2009 & NCAA \\
# 3:47.50 & Sharma (57.28), Mayfield (1:03.39), Byun (55.20), Chang (51.63) & 2024 & PP dual \\
# 3:47.47 & Crawford (56.67), Bacon-Brenes (1:03.67), Doi (56.21), Ngo (50.92) & 2017 & NCAA \\
# 3:47.44 & Sharma (57.35), Prawira (1:04.10), Mayfield (54.26), Kan (51.73) & 2025 & SCIAC \\
# 3:47.39 & Mitchum (56.66), Lewis (1:04.70), Dang (54.81), Orbach-M (51.22) & 2022 & SCIAC \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYearSite{800 FREE RELAY}{%
# 7:33.68 & Mitchum (1:54.13), Blake (1:54.89), Lewis (1:53.02), Campbell (1:51.64) & 2020 & SCIAC \\
# 7:34.20 & Byun (1:54.42), Nguyen (1:52.50), Sanders (1:55.00), Shaw (1:52.28) & 2025 & NCAA \\
# 7:35.15 & Umemoto (1:54.90), Hoffman (1:53.67), Orbach-M (1:53.17), El Masri (1:53.41) & 2019 & NCAA \\
# 7:31.24 & Lewis (1:53.84), Orbach-M (1:53.23), El Masri (1:53.04), Blake (1:51.13) & 2022 & NCAA \\
# 7:36.40 & Tran (1:55.01), Syme (1:53.76), Hoffman (1:51.56), Carrade (1:56.07) & 2018 & SCIAC \\
# 7:31.69 & Byun (1:51.75), Nguyen (1:53.84), Smith (1:53.70), Shaw (1:52.40) & 2024 & UCSB Invite \\
# 7:31.11 & Lewis (1:52.67), Hiebert (1:53.98), El Masri (1:53.48), Blake (1:50.98) & 2022 & SCIAC \\
# 7:36.94 & Ngo (1:52.91), Flaten (1:55.64), Doi (1:56.44), Deer (1:51.95) & 2015 & NCAA \\
# 7:37.09 & Rosenberger (1:54.16), Hoffman (1:54.44), Stacy (1:53.39), Carrade (1:55.10) & 2017 & SCIAC \\
# 7:29.28 & Byun (1:53.82), Shaw (1:51.41), Lewis (1:51.39), Blake (1:52.66) & 2023 & SCIAC \\
# }
# \end{subtable}
# \\[1em]
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{50 BACK - RELAY Spl.}{%
# 26.90 & Sammy Ennis & 2022 \\
# 26.68 & Annette Chang & 2025 \\
# 25.94 & Jocelyn Crawford & 2019 \\
# 27.14 & Erin MacLean & 2014 \\
# 26.82 & Stephanie Lewis & 2020 \\
# 25.98 & Annika Sharma & 2025 \\
# 26.22 & Jamee Mitchum & 2022 \\
# 26.28 & Kelly Ngo & 2017 \\
# 26.57 & Elsa Cheng & 2011 \\
# 26.97 & Sun Young Byun & 2025 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{50 FLY - RELAY Spl.}{%
# 24.05 & Ava Sealander & 2020 \\
# 25.24 & Stephanie Doi & 2017 \\
# 25.05 & Annika Jessen & 2014 \\
# 24.87 & Madeleine Kan & 2024 \\
# 24.85 & Lorea Gwo & 2015 \\
# 24.65 & Stephanie Lewis & 2019 \\
# 24.59 & Sun Young Byun & 2023 \\
# 24.58 & Katelyn Dang & 2022 \\
# 24.34 & Mackenzie Mayfield & 2025 \\
# 24.28 & Katie Bilotti & 2011 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{100 FLY - RELAY Spl.}{%
# 55.62 & Janet Tran & 2020 \\
# 55.27 & Lorea Gwo & 2015 \\
# 55.25 & Michele Kee & 2011 \\
# 55.20 & Sun Young Byun & 2024 \\
# 55.13 & Augusta Lewis & 2023 \\
# 54.91 & Katie Bilotti & 2009 \\
# 55.11 & Annika Jessen & 2014 \\
# 54.65 & Ava Sealander & 2022 \\
# 54.09 & Mackenzie Mayfield & 2025 \\
# 54.81 & Katelyn Dang & 2022 \\
# }
# \end{subtable}
# \\[1em]
# \caption{Events for Sheet CMS All Time Top 10, Sex Athena}
# \end{table}
#
#
# \begin{table}[h!]
# \centering
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{1-METER}{%
# 525.35 & Maia Presti & 2015 \\
# 512.05 & Emma Ng Pack & 2023 \\
# 494.95 & Izzy Doud & 2023 \\
# 462.15 & Carli Lessard & 2015 \\
# 514.70 & Makenna Parkinson & 2023 \\
# 458.95 & Alexis Romero & 2025 \\
# 458.60 & Meilan Uyeno & 2025 \\
# 433.40 & Josie Kearns & 2025 \\
# 426.15 & Pam Tanase & 1987 \\
# 422.90 & Jacque Desmond & 2019 \\
# }
# \end{subtable}
# %
# \begin{subtable}[t]{0.333\linewidth}\centering
# \eventtableTimeNameYear{3-METER}{%
# 441.40 & Jacque Desmond & 2020 \\
# 446.95 & Alexis Romero & 2025 \\
# 474.20 & Carli Lessard & 2016 \\
# 476.75 & Meilan Uyeno & 2025 \\
# 484.20 & Josie Kearns & 2025 \\
# 525.30 & Emma Ng Pack & 2023 \\
# 526.90 & Izzy Doud & 2023 \\
# 527.60 & Makenna Parkinson & 2023 \\
# 439.95 & Elena Goss & 1996 \\
# 428.05 & Carmen Lundell & 2013 \\
# }
# \end{subtable}
# %
# \caption{Events for Sheet CMS All Time Top 10, Sex Athena}
# \end{table}

# %%
# Check if the second CSV file exists
csv_file2 = OUT_FOLDER / "times_df - times_df.csv"
if csv_file2.exists():
    times_df2 = pd.read_csv(csv_file2)
    print(f"Loaded existing CSV file: {csv_file2}")
else:
    print(f"CSV file not found: {csv_file2}")
    print("You may need to create this file from your Excel data first.")
    # Create an empty dataframe for now
    times_df2 = pd.DataFrame()

times_df2.head()
# Out:
#                 SHEET     SEX    EVENT   TIME              NAME  YEAR TEAM  \
# 0           CMS at PP  Athena  50 FREE  23.29  Jocelyn Crawford  2018  NaN
# 1  CMS at PP Combined  Athena  50 FREE  23.89     Ava Sealander  2021  CMS
# 2  CMS at PP Combined  Athena  50 FREE  23.85   Francesca Coppo  2023   PP
# 3  CMS at PP Combined  Athena  50 FREE  23.67    Madison Kauahi  2017   PP
# 4  CMS at PP Combined  Athena  50 FREE  23.66     Madeleine Kan  2024  CMS
#
#    RANK SITE MEET CONTEXT
# 0   NaN  NaN  NaN     NaN
# 1   NaN  NaN  NaN     NaN
# 2   NaN  NaN  NaN     NaN
# 3   NaN  NaN  NaN     NaN
# 4   NaN  NaN  NaN     NaN

# %%
# Print all unique sheet names
unique_sheets = times_df2["SHEET"].dropna().unique()
print(sorted(unique_sheets))
# Out:
# ['CMS All Time Top 10', 'CMS Axelrood Pool Records', 'CMS Frosh Swimming & Diving Records', 'CMS SCIAC Champions', 'CMS at Cal Baptist Distance Meet', 'CMS at PP', 'CMS at PP Combined', 'CMS at UCSD', 'Development of Team Records (October 2001 to March 2025)', 'NCAA TOP 20', 'SCIAC All Time Top 10 Performers', 'SCIAC Records']

# %%
import pandas as pd
from pathlib import Path
import re

# Custom sheet and sex orders
sheet_order = [
    'CMS All Time Top 10', 'CMS Axelrood Pool Records', 'CMS Frosh Swimming & Diving Records',
    'Development of Team Records (October 2001 to March 2025)', 'CMS at UCSD',
    'CMS at Cal Baptist Distance Meet', 'CMS at PP', 'CMS at PP Combined',
    'CMS SCIAC Champions', 'SCIAC All Time Top 10 Performers', 'SCIAC Records', 'NCAA TOP 20'
]
sex_order = ["Women", "Athena", "Men", "Stag"]

# Convert sheet/sex to ordered categorical
times_df2["SHEET"] = pd.Categorical(times_df2["SHEET"], categories=sheet_order, ordered=True)
times_df2["SEX"] = pd.Categorical(times_df2["SEX"], categories=sex_order, ordered=True)

# Define event sort key as before
stroke_order = ["FREE", "BACK", "BREAST", "FLY", "IM"]

def event_sort_key(event):
    event_upper = event.upper()

    # Diving events
    if "METER" in event_upper:
        stroke_index = 999
        match = re.search(r'\d+', event_upper)
        distance = int(match.group()) if match else 0
        dives_match = re.search(r'\((\d+)\s*DIVES\)', event_upper)
        dives = int(dives_match.group(1)) if dives_match else 0
        return (stroke_index, distance, dives, event_upper)

    # Relay/Splits
    relay_flag = 1 if "RELAY" in event_upper or "SPL" in event_upper else 0

    # Individual strokes
    stroke_index = 0
    for i, stroke in enumerate(stroke_order):
        if stroke in event_upper:
            stroke_index = i
            break

    match = re.search(r'\d+', event_upper)
    distance = int(match.group()) if match else 0

    return (relay_flag, stroke_index, distance, event_upper)

# Convert EVENT to categorical based on custom key
unique_events = times_df2["EVENT"].dropna().unique()
sorted_events = sorted(unique_events, key=event_sort_key)
times_df2["EVENT"] = pd.Categorical(times_df2["EVENT"], categories=sorted_events, ordered=True)

# Sort by sheet → sex → event
times_df_sorted = times_df2.sort_values(by=["SHEET", "SEX", "EVENT"]).reset_index(drop=True)


times_df_sorted.to_csv(OUT_FOLDER / "times_df_sorted2.csv", index=False)

# %%
# Check if the final sorted CSV file exists
final_csv_file = OUT_FOLDER / "times_df_sorted2.csv"
if final_csv_file.exists():
    final_times_df = pd.read_csv(final_csv_file)
    print(f"Loaded existing CSV file: {final_csv_file}")
else:
    print(f"CSV file not found: {final_csv_file}")
    print("You may need to create this file from your Excel data first.")
    # Create an empty dataframe for now
    final_times_df = pd.DataFrame()

final_times_df.head()
# Out:
#                  SHEET     SEX    EVENT   TIME              NAME  YEAR TEAM  \
# 0  CMS All Time Top 10  Athena  50 FREE  23.29  Jocelyn Crawford  2019  NaN
# 1  CMS All Time Top 10  Athena  50 FREE  23.31     Ava Sealander  2022  NaN
# 2  CMS All Time Top 10  Athena  50 FREE  23.49         Kelly Ngo  2016  NaN
# 3  CMS All Time Top 10  Athena  50 FREE  23.77     Suzia Starzyk  2020  NaN
# 4  CMS All Time Top 10  Athena  50 FREE  23.71         Helen Liu  2014  NaN
#
#    RANK SITE MEET CONTEXT
# 0   NaN  NaN  NaN     NaN
# 1   NaN  NaN  NaN     NaN
# 2   NaN  NaN  NaN     NaN
# 3   NaN  NaN  NaN     NaN
# 4   NaN  NaN  NaN     NaN

# %%
import pandas as pd
from IPython.display import display, HTML
import ipywidgets as widgets
from IPython.display import clear_output

class SwimTableGenerator:
    def __init__(self, df):
        self.df = df
        self.selected_tables = []
        self.layout_config = {'per_row': 3, 'per_page': 9}

    def get_available_combinations(self):
        """Get all unique combinations of SHEET, SEX, EVENT in order they appear"""
        # Get unique combinations while preserving order
        seen = set()
        combinations_list = []

        for _, row in self.df.iterrows():
            combo = (row['SHEET'], row['SEX'], row['EVENT'])
            if combo not in seen:
                combinations_list.append({
                    'SHEET': row['SHEET'],
                    'SEX': row['SEX'],
                    'EVENT': row['EVENT']
                })
                seen.add(combo)

        combinations = pd.DataFrame(combinations_list)

        # Add count and display name
        for idx, row in combinations.iterrows():
            mask = ((self.df['SHEET'] == row['SHEET']) &
                   (self.df['SEX'] == row['SEX']) &
                   (self.df['EVENT'] == row['EVENT']))
            combinations.at[idx, 'count'] = mask.sum()

        combinations['display_name'] = (combinations['SHEET'] + ' - ' +
                                       combinations['SEX'] + ' - ' +
                                       combinations['EVENT'])
        return combinations

    def preview_table_data(self, sheet, sex, event):
        """Preview the data for a specific table"""
        mask = ((self.df['SHEET'] == sheet) &
                (self.df['SEX'] == sex) &
                (self.df['EVENT'] == event))
        return self.df[mask]

    def generate_table_latex(self, sheet, sex, event, use_inline=False):
        """Generate LaTeX for a single table"""
        data = self.preview_table_data(sheet, sex, event)
        title = event  # Only use the event name in caption

        # Sort by TIME (fastest to slowest)
        if 'TIME' in data.columns:
            # Convert TIME to numeric for proper sorting
            def time_to_seconds(time_str):
                if pd.isna(time_str):
                    return float('inf')
                try:
                    time_str = str(time_str).strip()
                    if ':' in time_str:
                        # Handle format like "1:50.30"
                        parts = time_str.split(':')
                        minutes = float(parts[0])
                        seconds = float(parts[1])
                        return minutes * 60 + seconds
                    else:
                        # Handle format like "23.29"
                        return float(time_str)
                except (ValueError, AttributeError):
                    return float('inf')

            data = data.copy()
            data['time_seconds'] = data['TIME'].apply(time_to_seconds)
            data = data.sort_values('time_seconds').drop('time_seconds', axis=1)
            data = data.reset_index(drop=True)  # Reset index after sorting

        # Determine which columns to use
        available_cols = []

        for col in ['TIME', 'NAME', 'YEAR', 'TEAM', 'RANK', 'SITE', 'MEET', 'CONTEXT']:
            if col in data.columns and not data[col].isna().all():
                available_cols.append(col)

        # Generate table rows
        rows = []
        for _, row in data.iterrows():
            row_data = []
            for col in available_cols:
                value = str(row[col]) if pd.notna(row[col]) else ""
                row_data.append(value)
            rows.append(" & ".join(row_data) + " \\\\")

        table_content = "\n".join(rows)

        # Generate macro name
        macro_suffix = "Mini" if use_inline else ""
        macro_name = f"\\eventtable{''.join(available_cols)}{macro_suffix}"

        return f"{macro_name}{{{title}}}{{\n{table_content}\n}}"

    def generate_layout_latex(self, layout_type='minipage'):
        """Generate complete LaTeX with layout"""
        if not self.selected_tables:
            return "No tables selected!"

        latex_output = []
        table_counter = 0
        per_row = self.layout_config['per_row']
        per_page = self.layout_config['per_page']

        if layout_type == 'minipage':
            minipage_width = f"{0.95/per_row:.2f}"

            for table_info in self.selected_tables:
                sheet, sex, event, _ = table_info

                # Start new row if needed
                if table_counter % per_row == 0:
                    if table_counter > 0:
                        latex_output.append("\\\\[0.5cm]")
                    latex_output.append("")

                # Use mini macro format for minipage
                table_latex = self.generate_table_latex(sheet, sex, event, use_inline=True)

                minipage = f"""\\begin{{minipage}}{{{minipage_width}\\textwidth}}
\\centering
{table_latex}
\\end{{minipage}}"""

                if table_counter % per_row < per_row - 1:
                    minipage += "\\hfill"

                latex_output.append(minipage)
                table_counter += 1

                # Page break if needed
                if table_counter % per_page == 0:
                    latex_output.append("\\newpage")

        elif layout_type == 'standalone':
            # Generate standalone tables using your original macros
            for table_info in self.selected_tables:
                sheet, sex, event, _ = table_info
                table_latex = self.generate_table_latex(sheet, sex, event, use_inline=False)
                latex_output.append(table_latex)
                latex_output.append("")  # Add space between tables

        elif layout_type == 'longtable':
            col_spec = "@{}" + "p{" + f"{0.9/per_row:.2f}" + "\\textwidth}" * per_row + "@{}"
            latex_output.append(f"\\begin{{longtable}}{{{col_spec}}}")

            tables_in_row = []
            for table_info in self.selected_tables:
                sheet, sex, event, _ = table_info
                table_latex = self.generate_table_latex(sheet, sex, event, use_inline=True)

                table_cell = f"\\parbox[t]{{{0.85/per_row:.2f}\\textwidth}}{{\\centering {table_latex}}}"
                tables_in_row.append(table_cell)

                if len(tables_in_row) == per_row:
                    latex_output.append(" & ".join(tables_in_row) + " \\\\[0.8cm]")
                    tables_in_row = []

            # Handle remaining tables
            if tables_in_row:
                while len(tables_in_row) < per_row:
                    tables_in_row.append("")
                latex_output.append(" & ".join(tables_in_row) + " \\\\")

            latex_output.append("\\end{longtable}")

        return "\n".join(latex_output)

# Initialize the generator
generator = SwimTableGenerator(final_times_df)

# Get available combinations
combinations = generator.get_available_combinations()
print("Available table combinations (in order of appearance):")
print(combinations[['display_name', 'count']].to_string(index=False))
# Out:
# Available table combinations (in order of appearance):
#                                                                                  display_name  count
#                                                        CMS All Time Top 10 - Athena - 50 FREE   10.0
#                                                       CMS All Time Top 10 - Athena - 100 FREE   10.0
#                                                       CMS All Time Top 10 - Athena - 200 FREE   10.0
#                                                       CMS All Time Top 10 - Athena - 500 FREE   10.0
#                                                      CMS All Time Top 10 - Athena - 1000 FREE   10.0
#                                                      CMS All Time Top 10 - Athena - 1650 FREE   10.0
#                                                       CMS All Time Top 10 - Athena - 100 BACK   10.0
#                                                       CMS All Time Top 10 - Athena - 200 BACK   10.0
#                                                     CMS All Time Top 10 - Athena - 100 BREAST   10.0
#                                                     CMS All Time Top 10 - Athena - 200 BREAST   10.0
#                                                        CMS All Time Top 10 - Athena - 100 FLY   10.0
#                                                        CMS All Time Top 10 - Athena - 200 FLY   10.0
#                                                         CMS All Time Top 10 - Athena - 200 IM   10.0
#                                                         CMS All Time Top 10 - Athena - 400 IM   10.0
#                                           CMS All Time Top 10 - Athena - 50 BRST - RELAY Spl.   10.0
#                                           CMS All Time Top 10 - Athena - 50 FREE - RELAY Spl.   10.0
#                                          CMS All Time Top 10 - Athena - 100 BRST - RELAY Spl.   10.0
#                                          CMS All Time Top 10 - Athena - 100 FREE - RELAY Spl.   10.0
#                                          CMS All Time Top 10 - Athena - 200 FREE - RELAY Spl.   10.0
#                                                 CMS All Time Top 10 - Athena - 200 FREE RELAY   11.0
#                                               CMS All Time Top 10 - Athena - 200 MEDLEY RELAY   10.0
#                                                 CMS All Time Top 10 - Athena - 400 FREE RELAY   10.0
#                                               CMS All Time Top 10 - Athena - 400 MEDLEY RELAY   10.0
#                                                 CMS All Time Top 10 - Athena - 800 FREE RELAY   10.0
#                                           CMS All Time Top 10 - Athena - 50 BACK - RELAY Spl.   10.0
#                                            CMS All Time Top 10 - Athena - 50 FLY - RELAY Spl.   10.0
#                                           CMS All Time Top 10 - Athena - 100 FLY - RELAY Spl.   10.0
#                                                        CMS All Time Top 10 - Athena - 1-METER   10.0
#                                                        CMS All Time Top 10 - Athena - 3-METER   10.0
#                                                          CMS All Time Top 10 - Stag - 50 FREE   10.0
#                                                         CMS All Time Top 10 - Stag - 100 FREE   10.0
#                                                         CMS All Time Top 10 - Stag - 200 FREE   10.0
#                                                         CMS All Time Top 10 - Stag - 500 FREE   10.0
#                                                        CMS All Time Top 10 - Stag - 1000 FREE   10.0
#                                                        CMS All Time Top 10 - Stag - 1650 FREE   10.0
#                                                         CMS All Time Top 10 - Stag - 100 BACK   10.0
#                                                         CMS All Time Top 10 - Stag - 200 BACK   10.0
#                                                       CMS All Time Top 10 - Stag - 100 BREAST   11.0
#                                                       CMS All Time Top 10 - Stag - 200 BREAST   10.0
#                                                          CMS All Time Top 10 - Stag - 100 FLY   10.0
#                                                          CMS All Time Top 10 - Stag - 200 FLY   10.0
#                                                           CMS All Time Top 10 - Stag - 200 IM   10.0
#                                                           CMS All Time Top 10 - Stag - 400 IM   10.0
#                                             CMS All Time Top 10 - Stag - 50 BRST - RELAY Spl.   10.0
#                                             CMS All Time Top 10 - Stag - 50 FREE - RELAY Spl.   10.0
#                                            CMS All Time Top 10 - Stag - 100 BRST - RELAY Spl.   10.0
#                                            CMS All Time Top 10 - Stag - 100 FREE - RELAY Spl.   10.0
#                                            CMS All Time Top 10 - Stag - 200 FREE - RELAY Spl.   10.0
#                                                   CMS All Time Top 10 - Stag - 200 FREE RELAY   10.0
#                                                 CMS All Time Top 10 - Stag - 200 MEDLEY RELAY   10.0
#                                                   CMS All Time Top 10 - Stag - 400 FREE RELAY   10.0
#                                                 CMS All Time Top 10 - Stag - 400 MEDLEY RELAY   10.0
#                                                   CMS All Time Top 10 - Stag - 800 FREE RELAY   10.0
#                                             CMS All Time Top 10 - Stag - 50 BACK - RELAY Spl.   10.0
#                                              CMS All Time Top 10 - Stag - 50 FLY - RELAY Spl.   10.0
#                                             CMS All Time Top 10 - Stag - 100 FLY - RELAY Spl.   10.0
#                                                          CMS All Time Top 10 - Stag - 1-METER   10.0
#                                                          CMS All Time Top 10 - Stag - 3-METER   10.0
#                                                   CMS Axelrood Pool Records - Women - 50 FREE    1.0
#                                                  CMS Axelrood Pool Records - Women - 100 FREE    1.0
#                                                  CMS Axelrood Pool Records - Women - 200 FREE    1.0
#                                                  CMS Axelrood Pool Records - Women - 500 FREE    1.0
#                                                 CMS Axelrood Pool Records - Women - 1000 FREE    1.0
#                                                 CMS Axelrood Pool Records - Women - 1650 FREE    1.0
#                                                  CMS Axelrood Pool Records - Women - 100 BACK    1.0
#                                                  CMS Axelrood Pool Records - Women - 200 BACK    1.0
#                                                CMS Axelrood Pool Records - Women - 100 BREAST    1.0
#                                                CMS Axelrood Pool Records - Women - 200 BREAST    1.0
#                                                   CMS Axelrood Pool Records - Women - 100 FLY    1.0
#                                                   CMS Axelrood Pool Records - Women - 200 FLY    1.0
#                                                    CMS Axelrood Pool Records - Women - 200 IM    1.0
#                                                    CMS Axelrood Pool Records - Women - 400 IM    1.0
#                                            CMS Axelrood Pool Records - Women - 200 FREE RELAY    1.0
#                                          CMS Axelrood Pool Records - Women - 200 MEDLEY RELAY    1.0
#                                            CMS Axelrood Pool Records - Women - 400 FREE RELAY    1.0
#                                          CMS Axelrood Pool Records - Women - 400 MEDLEY RELAY    1.0
#                                            CMS Axelrood Pool Records - Women - 800 FREE RELAY    1.0
#                                                   CMS Axelrood Pool Records - Women - 1-METER    1.0
#                                                   CMS Axelrood Pool Records - Women - 3-METER    1.0
#                                                     CMS Axelrood Pool Records - Men - 50 FREE    1.0
#                                                    CMS Axelrood Pool Records - Men - 100 FREE    1.0
#                                                    CMS Axelrood Pool Records - Men - 200 FREE    1.0
#                                                    CMS Axelrood Pool Records - Men - 500 FREE    1.0
#                                                   CMS Axelrood Pool Records - Men - 1000 FREE    1.0
#                                                   CMS Axelrood Pool Records - Men - 1650 FREE    1.0
#                                                    CMS Axelrood Pool Records - Men - 100 BACK    1.0
#                                                    CMS Axelrood Pool Records - Men - 200 BACK    1.0
#                                                  CMS Axelrood Pool Records - Men - 100 BREAST    1.0
#                                                  CMS Axelrood Pool Records - Men - 200 BREAST    1.0
#                                                     CMS Axelrood Pool Records - Men - 100 FLY    1.0
#                                                     CMS Axelrood Pool Records - Men - 200 FLY    1.0
#                                                      CMS Axelrood Pool Records - Men - 200 IM    1.0
#                                                      CMS Axelrood Pool Records - Men - 400 IM    1.0
#                                              CMS Axelrood Pool Records - Men - 200 FREE RELAY    1.0
#                                            CMS Axelrood Pool Records - Men - 200 MEDLEY RELAY    1.0
#                                              CMS Axelrood Pool Records - Men - 400 FREE RELAY    1.0
#                                            CMS Axelrood Pool Records - Men - 400 MEDLEY RELAY    1.0
#                                              CMS Axelrood Pool Records - Men - 800 FREE RELAY    1.0
#                                                     CMS Axelrood Pool Records - Men - 1-METER    1.0
#                                                     CMS Axelrood Pool Records - Men - 3-METER    1.0
#                                        CMS Frosh Swimming & Diving Records - Athena - 50 FREE    1.0
#                                       CMS Frosh Swimming & Diving Records - Athena - 100 FREE    1.0
#                                       CMS Frosh Swimming & Diving Records - Athena - 200 FREE    1.0
#                                       CMS Frosh Swimming & Diving Records - Athena - 500 FREE    1.0
#                                      CMS Frosh Swimming & Diving Records - Athena - 1650 FREE    1.0
#                                       CMS Frosh Swimming & Diving Records - Athena - 100 BACK    1.0
#                                       CMS Frosh Swimming & Diving Records - Athena - 200 BACK    1.0
#                                     CMS Frosh Swimming & Diving Records - Athena - 100 BREAST    1.0
#                                     CMS Frosh Swimming & Diving Records - Athena - 200 BREAST    1.0
#                                        CMS Frosh Swimming & Diving Records - Athena - 100 FLY    1.0
#                                        CMS Frosh Swimming & Diving Records - Athena - 200 FLY    1.0
#                                         CMS Frosh Swimming & Diving Records - Athena - 200 IM    1.0
#                                         CMS Frosh Swimming & Diving Records - Athena - 400 IM    1.0
#                                        CMS Frosh Swimming & Diving Records - Athena - 1-METER    1.0
#                                        CMS Frosh Swimming & Diving Records - Athena - 3-METER    1.0
#                                          CMS Frosh Swimming & Diving Records - Stag - 50 FREE    1.0
#                                         CMS Frosh Swimming & Diving Records - Stag - 100 FREE    1.0
#                                         CMS Frosh Swimming & Diving Records - Stag - 200 FREE    1.0
#                                         CMS Frosh Swimming & Diving Records - Stag - 500 FREE    1.0
#                                        CMS Frosh Swimming & Diving Records - Stag - 1650 FREE    1.0
#                                         CMS Frosh Swimming & Diving Records - Stag - 100 BACK    1.0
#                                         CMS Frosh Swimming & Diving Records - Stag - 200 BACK    1.0
#                                       CMS Frosh Swimming & Diving Records - Stag - 100 BREAST    1.0
#                                       CMS Frosh Swimming & Diving Records - Stag - 200 BREAST    1.0
#                                          CMS Frosh Swimming & Diving Records - Stag - 100 FLY    1.0
#                                          CMS Frosh Swimming & Diving Records - Stag - 200 FLY    1.0
#                                           CMS Frosh Swimming & Diving Records - Stag - 200 IM    1.0
#                                           CMS Frosh Swimming & Diving Records - Stag - 400 IM    1.0
#                                          CMS Frosh Swimming & Diving Records - Stag - 1-METER    1.0
#                                          CMS Frosh Swimming & Diving Records - Stag - 3-METER    1.0
#                   Development of Team Records (October 2001 to March 2025) - Athena - 50 FREE   15.0
#                  Development of Team Records (October 2001 to March 2025) - Athena - 100 FREE   11.0
#                  Development of Team Records (October 2001 to March 2025) - Athena - 200 FREE    6.0
#                  Development of Team Records (October 2001 to March 2025) - Athena - 500 FREE    5.0
#                 Development of Team Records (October 2001 to March 2025) - Athena - 1000 FREE    1.0
#                 Development of Team Records (October 2001 to March 2025) - Athena - 1650 FREE    1.0
#                  Development of Team Records (October 2001 to March 2025) - Athena - 100 BACK    9.0
#                  Development of Team Records (October 2001 to March 2025) - Athena - 200 BACK    8.0
#                Development of Team Records (October 2001 to March 2025) - Athena - 100 BREAST    6.0
#                Development of Team Records (October 2001 to March 2025) - Athena - 200 BREAST    9.0
#                   Development of Team Records (October 2001 to March 2025) - Athena - 100 FLY    8.0
#                   Development of Team Records (October 2001 to March 2025) - Athena - 200 FLY    7.0
#                    Development of Team Records (October 2001 to March 2025) - Athena - 200 IM   10.0
#                    Development of Team Records (October 2001 to March 2025) - Athena - 400 IM    9.0
#            Development of Team Records (October 2001 to March 2025) - Athena - 200 FREE RELAY   13.0
#          Development of Team Records (October 2001 to March 2025) - Athena - 200 MEDLEY RELAY   12.0
#            Development of Team Records (October 2001 to March 2025) - Athena - 400 FREE RELAY    7.0
#          Development of Team Records (October 2001 to March 2025) - Athena - 400 MEDLEY RELAY    8.0
#            Development of Team Records (October 2001 to March 2025) - Athena - 800 FREE RELAY   11.0
#        Development of Team Records (October 2001 to March 2025) - Athena - 1-METER (11 dives)    1.0
#        Development of Team Records (October 2001 to March 2025) - Athena - 3-METER (11 dives)    4.0
#                     Development of Team Records (October 2001 to March 2025) - Stag - 50 FREE    5.0
#                    Development of Team Records (October 2001 to March 2025) - Stag - 100 FREE    5.0
#                    Development of Team Records (October 2001 to March 2025) - Stag - 200 FREE    6.0
#                    Development of Team Records (October 2001 to March 2025) - Stag - 500 FREE    7.0
#                   Development of Team Records (October 2001 to March 2025) - Stag - 1000 FREE    6.0
#                   Development of Team Records (October 2001 to March 2025) - Stag - 1650 FREE    7.0
#                    Development of Team Records (October 2001 to March 2025) - Stag - 100 BACK   10.0
#                    Development of Team Records (October 2001 to March 2025) - Stag - 200 BACK    5.0
#                  Development of Team Records (October 2001 to March 2025) - Stag - 100 BREAST    8.0
#                  Development of Team Records (October 2001 to March 2025) - Stag - 200 BREAST    3.0
#                     Development of Team Records (October 2001 to March 2025) - Stag - 100 FLY    8.0
#                     Development of Team Records (October 2001 to March 2025) - Stag - 200 FLY   12.0
#                      Development of Team Records (October 2001 to March 2025) - Stag - 200 IM    1.0
#                      Development of Team Records (October 2001 to March 2025) - Stag - 400 IM    1.0
#              Development of Team Records (October 2001 to March 2025) - Stag - 200 FREE RELAY    7.0
#            Development of Team Records (October 2001 to March 2025) - Stag - 200 MEDLEY RELAY   11.0
#              Development of Team Records (October 2001 to March 2025) - Stag - 400 FREE RELAY    4.0
#            Development of Team Records (October 2001 to March 2025) - Stag - 400 MEDLEY RELAY   11.0
#              Development of Team Records (October 2001 to March 2025) - Stag - 800 FREE RELAY    7.0
#                     Development of Team Records (October 2001 to March 2025) - Stag - 1-METER    6.0
#                     Development of Team Records (October 2001 to March 2025) - Stag - 3-METER    6.0
#                                                                CMS at UCSD - Athena - 50 FREE   10.0
#                                                               CMS at UCSD - Athena - 100 FREE   10.0
#                                                               CMS at UCSD - Athena - 200 FREE   10.0
#                                                               CMS at UCSD - Athena - 500 FREE   10.0
#                                                              CMS at UCSD - Athena - 1000 FREE   10.0
#                                                               CMS at UCSD - Athena - 100 BACK   10.0
#                                                               CMS at UCSD - Athena - 200 BACK   10.0
#                                                             CMS at UCSD - Athena - 100 BREAST   10.0
#                                                             CMS at UCSD - Athena - 200 BREAST   10.0
#                                                                CMS at UCSD - Athena - 100 FLY   10.0
#                                                                CMS at UCSD - Athena - 200 FLY   10.0
#                                                                 CMS at UCSD - Athena - 200 IM   10.0
#                                                                 CMS at UCSD - Athena - 400 IM   10.0
#                                                         CMS at UCSD - Athena - 200 FREE RELAY    3.0
#                                                       CMS at UCSD - Athena - 200 MEDLEY RELAY   10.0
#                                                         CMS at UCSD - Athena - 400 FREE RELAY   10.0
#                                                                CMS at UCSD - Athena - 1-METER   10.0
#                                                                CMS at UCSD - Athena - 3-METER   10.0
#                                                                  CMS at UCSD - Stag - 50 FREE   11.0
#                                                                 CMS at UCSD - Stag - 100 FREE   11.0
#                                                                 CMS at UCSD - Stag - 200 FREE   10.0
#                                                                 CMS at UCSD - Stag - 500 FREE   10.0
#                                                                CMS at UCSD - Stag - 1000 FREE   10.0
#                                                                 CMS at UCSD - Stag - 100 BACK   10.0
#                                                                 CMS at UCSD - Stag - 200 BACK   11.0
#                                                               CMS at UCSD - Stag - 100 BREAST   10.0
#                                                               CMS at UCSD - Stag - 200 BREAST   10.0
#                                                                  CMS at UCSD - Stag - 100 FLY   10.0
#                                                                  CMS at UCSD - Stag - 200 FLY   10.0
#                                                                   CMS at UCSD - Stag - 200 IM   10.0
#                                                                   CMS at UCSD - Stag - 400 IM   10.0
#                                                           CMS at UCSD - Stag - 200 FREE RELAY    4.0
#                                                         CMS at UCSD - Stag - 200 MEDLEY RELAY   10.0
#                                                           CMS at UCSD - Stag - 400 FREE RELAY   10.0
#                                                                  CMS at UCSD - Stag - 1-METER   10.0
#                                                                  CMS at UCSD - Stag - 3-METER   10.0
#                                           CMS at Cal Baptist Distance Meet - Athena - 50 FREE   10.0
#                                          CMS at Cal Baptist Distance Meet - Athena - 100 FREE   10.0
#                                          CMS at Cal Baptist Distance Meet - Athena - 200 FREE   10.0
#                                          CMS at Cal Baptist Distance Meet - Athena - 500 FREE   10.0
#                                         CMS at Cal Baptist Distance Meet - Athena - 1000 FREE   10.0
#                                         CMS at Cal Baptist Distance Meet - Athena - 1650 FREE   10.0
#                                          CMS at Cal Baptist Distance Meet - Athena - 300 BACK   10.0
#                                        CMS at Cal Baptist Distance Meet - Athena - 300 BREAST   10.0
#                                           CMS at Cal Baptist Distance Meet - Athena - 300 FLY   10.0
#                                            CMS at Cal Baptist Distance Meet - Athena - 300 IM   10.0
#                  CMS at Cal Baptist Distance Meet - Athena - 500 FREE RELAY- (50-100-150-200)   10.0
# CMS at Cal Baptist Distance Meet - Athena - 500 MEDLEY RELAY - (200 BACK-150 BR-100 FL-50 FS)   10.0
#                                 CMS at Cal Baptist Distance Meet - Athena - 1-METER (6 dives)   10.0
#                                CMS at Cal Baptist Distance Meet - Athena - 1-METER (11 dives)    1.0
#                                 CMS at Cal Baptist Distance Meet - Athena - 3-METER (6 dives)   10.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                                           NaN    0.0
#                                                                  CMS at PP - Athena - 50 FREE   10.0
#                                                                 CMS at PP - Athena - 100 FREE   10.0
#                                                                 CMS at PP - Athena - 200 FREE   10.0
#                                                                 CMS at PP - Athena - 500 FREE   10.0
#                                                                CMS at PP - Athena - 1650 FREE   10.0
#                                                                 CMS at PP - Athena - 100 BACK   10.0
#                                                                 CMS at PP - Athena - 200 BACK   10.0
#                                                               CMS at PP - Athena - 100 BREAST   10.0
#                                                               CMS at PP - Athena - 200 BREAST   10.0
#                                                                  CMS at PP - Athena - 100 FLY   10.0
#                                                                  CMS at PP - Athena - 200 FLY   10.0
#                                                                   CMS at PP - Athena - 200 IM   10.0
#                                                                   CMS at PP - Athena - 400 IM   10.0
#                                                           CMS at PP - Athena - 200 FREE RELAY   10.0
#                                                         CMS at PP - Athena - 200 MEDLEY RELAY   10.0
#                                                           CMS at PP - Athena - 400 FREE RELAY   10.0
#                                                         CMS at PP - Athena - 400 MEDLEY RELAY   10.0
#                                                                  CMS at PP - Athena - 1-METER   10.0
#                                                                  CMS at PP - Athena - 3-METER   10.0
#                                                                    CMS at PP - Stag - 50 FREE   10.0
#                                                                   CMS at PP - Stag - 100 FREE   10.0
#                                                                   CMS at PP - Stag - 200 FREE   10.0
#                                                                   CMS at PP - Stag - 500 FREE   10.0
#                                                                  CMS at PP - Stag - 1650 FREE   20.0
#                                                                   CMS at PP - Stag - 200 BACK   10.0
#                                                                 CMS at PP - Stag - 100 BREAST   10.0
#                                                                 CMS at PP - Stag - 200 BREAST   10.0
#                                                                    CMS at PP - Stag - 100 FLY   10.0
#                                                                    CMS at PP - Stag - 200 FLY   10.0
#                                                                     CMS at PP - Stag - 200 IM   10.0
#                                                                     CMS at PP - Stag - 400 IM   10.0
#                                                             CMS at PP - Stag - 200 FREE RELAY   10.0
#                                                           CMS at PP - Stag - 200 MEDLEY RELAY   10.0
#                                                             CMS at PP - Stag - 400 FREE RELAY   10.0
#                                                           CMS at PP - Stag - 400 MEDLEY RELAY   10.0
#                                                                    CMS at PP - Stag - 1-METER   10.0
#                                                                    CMS at PP - Stag - 3-METER   10.0
#                                                         CMS at PP Combined - Athena - 50 FREE   10.0
#                                                        CMS at PP Combined - Athena - 100 FREE   10.0
#                                                        CMS at PP Combined - Athena - 200 FREE   10.0
#                                                        CMS at PP Combined - Athena - 500 FREE   10.0
#                                                       CMS at PP Combined - Athena - 1650 FREE   10.0
#                                                        CMS at PP Combined - Athena - 100 BACK   11.0
#                                                        CMS at PP Combined - Athena - 200 BACK   10.0
#                                                      CMS at PP Combined - Athena - 100 BREAST   10.0
#                                                      CMS at PP Combined - Athena - 200 BREAST   10.0
#                                                         CMS at PP Combined - Athena - 100 FLY   10.0
#                                                         CMS at PP Combined - Athena - 200 FLY   10.0
#                                                          CMS at PP Combined - Athena - 200 IM   10.0
#                                                          CMS at PP Combined - Athena - 400 IM   10.0
#                                                         CMS at PP Combined - Athena - 1-METER   10.0
#                                                         CMS at PP Combined - Athena - 3-METER   10.0
#                                                           CMS at PP Combined - Stag - 50 FREE   10.0
#                                                          CMS at PP Combined - Stag - 100 FREE   10.0
#                                                          CMS at PP Combined - Stag - 200 FREE   10.0
#                                                          CMS at PP Combined - Stag - 500 FREE   10.0
#                                                         CMS at PP Combined - Stag - 1650 FREE   10.0
#                                                          CMS at PP Combined - Stag - 100 BACK   10.0
#                                                          CMS at PP Combined - Stag - 200 BACK   10.0
#                                                        CMS at PP Combined - Stag - 100 BREAST   10.0
#                                                        CMS at PP Combined - Stag - 200 BREAST   10.0
#                                                           CMS at PP Combined - Stag - 100 FLY   10.0
#                                                           CMS at PP Combined - Stag - 200 FLY   10.0
#                                                            CMS at PP Combined - Stag - 200 IM   10.0
#                                                            CMS at PP Combined - Stag - 400 IM   10.0
#                                                    CMS at PP Combined - Stag - 200 FREE RELAY   10.0
#                                                  CMS at PP Combined - Stag - 200 MEDLEY RELAY   10.0
#                                                    CMS at PP Combined - Stag - 400 FREE RELAY   10.0
#                                                  CMS at PP Combined - Stag - 400 MEDLEY RELAY   10.0
#                                                           CMS at PP Combined - Stag - 1-METER   10.0
#                                                           CMS at PP Combined - Stag - 3-METER   10.0
#                                                        CMS SCIAC Champions - Athena - 50 FREE   12.0
#                                                       CMS SCIAC Champions - Athena - 100 FREE   10.0
#                                                       CMS SCIAC Champions - Athena - 200 FREE    4.0
#                                                       CMS SCIAC Champions - Athena - 500 FREE   13.0
#                                                      CMS SCIAC Champions - Athena - 1650 FREE   17.0
#                                                        CMS SCIAC Champions - Athena - 50 BACK    1.0
#                                                       CMS SCIAC Champions - Athena - 100 BACK   14.0
#                                                       CMS SCIAC Champions - Athena - 200 BACK   16.0
#                                                      CMS SCIAC Champions - Athena - 50 BREAST    3.0
#                                                     CMS SCIAC Champions - Athena - 100 BREAST   21.0
#                                                     CMS SCIAC Champions - Athena - 200 BREAST   17.0
#                                                        CMS SCIAC Champions - Athena - 100 FLY   19.0
#                                                        CMS SCIAC Champions - Athena - 200 FLY   10.0
#                                                         CMS SCIAC Champions - Athena - 200 IM   17.0
#                                                         CMS SCIAC Champions - Athena - 400 IM   14.0
#                                                        CMS SCIAC Champions - Athena - 1-METER   12.0
#                                                        CMS SCIAC Champions - Athena - 3-METER   10.0
#                                                          CMS SCIAC Champions - Stag - 50 FREE   18.0
#                                                         CMS SCIAC Champions - Stag - 100 FREE   16.0
#                                                         CMS SCIAC Champions - Stag - 200 FREE   11.0
#                                                         CMS SCIAC Champions - Stag - 500 FREE   25.0
#                                                        CMS SCIAC Champions - Stag - 1650 FREE   20.0
#                                                         CMS SCIAC Champions - Stag - 100 BACK    9.0
#                                                         CMS SCIAC Champions - Stag - 200 BACK   15.0
#                                                       CMS SCIAC Champions - Stag - 100 BREAST   14.0
#                                                       CMS SCIAC Champions - Stag - 200 BREAST   18.0
#                                                          CMS SCIAC Champions - Stag - 100 FLY   15.0
#                                                          CMS SCIAC Champions - Stag - 200 FLY   11.0
#                                                           CMS SCIAC Champions - Stag - 200 IM   16.0
#                                                           CMS SCIAC Champions - Stag - 400 IM   17.0
#                                                          CMS SCIAC Champions - Stag - 1-METER   12.0
#                                                          CMS SCIAC Champions - Stag - 3-METER   10.0
#                                           SCIAC All Time Top 10 Performers - Athena - 50 FREE   11.0
#                                          SCIAC All Time Top 10 Performers - Athena - 100 FREE   10.0
#                                          SCIAC All Time Top 10 Performers - Athena - 200 FREE   10.0
#                                          SCIAC All Time Top 10 Performers - Athena - 500 FREE   10.0
#                                         SCIAC All Time Top 10 Performers - Athena - 1650 FREE   10.0
#                                          SCIAC All Time Top 10 Performers - Athena - 100 BACK   10.0
#                                          SCIAC All Time Top 10 Performers - Athena - 200 BACK   10.0
#                                        SCIAC All Time Top 10 Performers - Athena - 100 BREAST   10.0
#                                        SCIAC All Time Top 10 Performers - Athena - 200 BREAST   10.0
#                                           SCIAC All Time Top 10 Performers - Athena - 100 FLY   10.0
#                                           SCIAC All Time Top 10 Performers - Athena - 200 FLY   10.0
#                                            SCIAC All Time Top 10 Performers - Athena - 200 IM   10.0
#                                            SCIAC All Time Top 10 Performers - Athena - 400 IM   10.0
#                                SCIAC All Time Top 10 Performers - Athena - 1-METER (11 dives)   10.0
#                                SCIAC All Time Top 10 Performers - Athena - 3-METER (11 dives)   10.0
#                                             SCIAC All Time Top 10 Performers - Stag - 50 FREE   10.0
#                                            SCIAC All Time Top 10 Performers - Stag - 100 FREE   10.0
#                                            SCIAC All Time Top 10 Performers - Stag - 200 FREE   10.0
#                                            SCIAC All Time Top 10 Performers - Stag - 500 FREE   10.0
#                                           SCIAC All Time Top 10 Performers - Stag - 1650 FREE   10.0
#                                            SCIAC All Time Top 10 Performers - Stag - 100 BACK   10.0
#                                            SCIAC All Time Top 10 Performers - Stag - 200 BACK   10.0
#                                          SCIAC All Time Top 10 Performers - Stag - 100 BREAST   10.0
#                                          SCIAC All Time Top 10 Performers - Stag - 200 BREAST   10.0
#                                             SCIAC All Time Top 10 Performers - Stag - 100 FLY   10.0
#                                             SCIAC All Time Top 10 Performers - Stag - 200 FLY   10.0
#                                              SCIAC All Time Top 10 Performers - Stag - 200 IM   10.0
#                                              SCIAC All Time Top 10 Performers - Stag - 400 IM   10.0
#                                  SCIAC All Time Top 10 Performers - Stag - 1-METER (11 dives)   10.0
#                                  SCIAC All Time Top 10 Performers - Stag - 3-METER (11 dives)   10.0
#                                                               SCIAC Records - Women - 50 FREE    2.0
#                                                              SCIAC Records - Women - 100 FREE    2.0
#                                                              SCIAC Records - Women - 200 FREE    2.0
#                                                              SCIAC Records - Women - 500 FREE    2.0
#                                                             SCIAC Records - Women - 1650 FREE    2.0
#                                                              SCIAC Records - Women - 100 BACK    2.0
#                                                              SCIAC Records - Women - 200 BACK    2.0
#                                                            SCIAC Records - Women - 100 BREAST    2.0
#                                                            SCIAC Records - Women - 200 BREAST    2.0
#                                                               SCIAC Records - Women - 100 FLY    2.0
#                                                               SCIAC Records - Women - 200 FLY    2.0
#                                                                SCIAC Records - Women - 200 IM    2.0
#                                                                SCIAC Records - Women - 400 IM    2.0
#                                                        SCIAC Records - Women - 200 FREE RELAY    2.0
#                                                      SCIAC Records - Women - 200 MEDLEY RELAY    2.0
#                                                        SCIAC Records - Women - 400 FREE RELAY    2.0
#                                                      SCIAC Records - Women - 400 MEDLEY RELAY    2.0
#                                                        SCIAC Records - Women - 800 FREE RELAY    2.0
#                                                               SCIAC Records - Women - 1-METER    2.0
#                                                               SCIAC Records - Women - 3-METER    2.0
#                                                                 SCIAC Records - Men - 50 FREE    2.0
#                                                                SCIAC Records - Men - 100 FREE    2.0
#                                                                SCIAC Records - Men - 200 FREE    2.0
#                                                                SCIAC Records - Men - 500 FREE    2.0
#                                                               SCIAC Records - Men - 1650 FREE    2.0
#                                                                SCIAC Records - Men - 100 BACK    2.0
#                                                                SCIAC Records - Men - 200 BACK    2.0
#                                                              SCIAC Records - Men - 100 BREAST    2.0
#                                                              SCIAC Records - Men - 200 BREAST    2.0
#                                                                 SCIAC Records - Men - 100 FLY    2.0
#                                                                 SCIAC Records - Men - 200 FLY    2.0
#                                                                  SCIAC Records - Men - 200 IM    2.0
#                                                                  SCIAC Records - Men - 400 IM    2.0
#                                                          SCIAC Records - Men - 200 FREE RELAY    2.0
#                                                        SCIAC Records - Men - 200 MEDLEY RELAY    2.0
#                                                          SCIAC Records - Men - 400 FREE RELAY    2.0
#                                                        SCIAC Records - Men - 400 MEDLEY RELAY    2.0
#                                                          SCIAC Records - Men - 800 FREE RELAY    2.0
#                                                                 SCIAC Records - Men - 1-METER    2.0
#                                                                 SCIAC Records - Men - 3-METER    2.0
#                                                                 NCAA TOP 20 - Women - 50 FREE   21.0
#                                                                NCAA TOP 20 - Women - 100 FREE   20.0
#                                                                NCAA TOP 20 - Women - 200 FREE   20.0
#                                                                NCAA TOP 20 - Women - 500 FREE   20.0
#                                                               NCAA TOP 20 - Women - 1650 FREE   20.0
#                                                                NCAA TOP 20 - Women - 100 BACK   20.0
#                                                                NCAA TOP 20 - Women - 200 BACK   20.0
#                                                              NCAA TOP 20 - Women - 100 BREAST   20.0
#                                                              NCAA TOP 20 - Women - 200 BREAST   20.0
#                                                                 NCAA TOP 20 - Women - 100 FLY   20.0
#                                                                 NCAA TOP 20 - Women - 200 FLY   20.0
#                                                                  NCAA TOP 20 - Women - 200 IM   20.0
#                                                                  NCAA TOP 20 - Women - 400 IM   20.0
#                                                            NCAA TOP 20 - Women - 50 FREE Spl.   22.0
#                                                           NCAA TOP 20 - Women - 100 FREE Spl.   20.0
#                                                          NCAA TOP 20 - Women - 200 FREE RELAY   20.0
#                                                           NCAA TOP 20 - Women - 200 FREE Spl.   20.0
#                                                        NCAA TOP 20 - Women - 200 MEDLEY RELAY   20.0
#                                                          NCAA TOP 20 - Women - 400 FREE RELAY   20.0
#                                                        NCAA TOP 20 - Women - 400 MEDLEY RELAY   20.0
#                                                          NCAA TOP 20 - Women - 800 FREE RELAY   20.0
#                                                            NCAA TOP 20 - Women - 50 BACK Spl.   20.0
#                                                          NCAA TOP 20 - Women - 50 BREAST Spl.   20.0
#                                                         NCAA TOP 20 - Women - 100 BREAST Spl.   20.0
#                                                             NCAA TOP 20 - Women - 50 FLY Spl.   20.0
#                                                            NCAA TOP 20 - Women - 100 FLY Spl.   20.0
#                                                                   NCAA TOP 20 - Men - 50 FREE   20.0
#                                                                  NCAA TOP 20 - Men - 100 FREE   20.0
#                                                                  NCAA TOP 20 - Men - 200 FREE   20.0
#                                                                  NCAA TOP 20 - Men - 500 FREE   20.0
#                                                                 NCAA TOP 20 - Men - 1650 FREE   20.0
#                                                                  NCAA TOP 20 - Men - 100 BACK   21.0
#                                                                  NCAA TOP 20 - Men - 200 BACK   20.0
#                                                                NCAA TOP 20 - Men - 100 BREAST   20.0
#                                                                NCAA TOP 20 - Men - 200 BREAST   20.0
#                                                                   NCAA TOP 20 - Men - 100 FLY   20.0
#                                                                   NCAA TOP 20 - Men - 200 FLY   20.0
#                                                                    NCAA TOP 20 - Men - 200 IM   20.0
#                                                                    NCAA TOP 20 - Men - 400 IM   20.0
#                                                              NCAA TOP 20 - Men - 50 FREE Spl.   20.0
#                                                             NCAA TOP 20 - Men - 100 FREE Spl.   21.0
#                                                            NCAA TOP 20 - Men - 200 FREE RELAY   20.0
#                                                             NCAA TOP 20 - Men - 200 FREE Spl.   20.0
#                                                          NCAA TOP 20 - Men - 200 MEDLEY RELAY   20.0
#                                                            NCAA TOP 20 - Men - 400 FREE RELAY   20.0
#                                                          NCAA TOP 20 - Men - 400 MEDLEY RELAY   21.0
#                                                            NCAA TOP 20 - Men - 800 FREE RELAY   21.0
#                                                              NCAA TOP 20 - Men - 50 BACK Spl.   20.0
#                                                            NCAA TOP 20 - Men - 50 BREAST Spl.   20.0
#                                                           NCAA TOP 20 - Men - 100 BREAST Spl.   20.0
#                                                               NCAA TOP 20 - Men - 50 FLY Spl.   20.0
#                                                              NCAA TOP 20 - Men - 100 FLY Spl.   20.0

# %%
def create_table_interface():
    combinations = generator.get_available_combinations()

    # Widgets - dropdown maintains order from dataframe
    table_dropdown = widgets.Dropdown(
        options=[(row['display_name'], (row['SHEET'], row['SEX'], row['EVENT']))
                for _, row in combinations.iterrows()],
        description='Select Table:',
        style={'description_width': 'initial'}
    )

    add_button = widgets.Button(description='Add Table', button_style='success')
    preview_button = widgets.Button(description='Preview Data', button_style='info')

    # Layout configuration
    per_row_slider = widgets.IntSlider(
        value=2, min=1, max=4, description='Tables per row:',
        style={'description_width': 'initial'}
    )

    per_page_slider = widgets.IntSlider(
        value=6, min=3, max=16, description='Tables per page:',
        style={'description_width': 'initial'}
    )

    layout_dropdown = widgets.Dropdown(
        options=[
            ('Minipage (side by side)', 'minipage'),
            ('Standalone (your macros)', 'standalone'),
            ('Longtable (grid)', 'longtable')
        ],
        value='minipage',
        description='Layout type:',
        style={'description_width': 'initial'}
    )

    generate_button = widgets.Button(description='Generate LaTeX', button_style='primary')
    clear_button = widgets.Button(description='Clear Selection', button_style='warning')

    output = widgets.Output()

    def add_table(b):
        sheet, sex, event = table_dropdown.value
        generator.selected_tables.append((sheet, sex, event, False))

        with output:
            clear_output()
            print(f"Added: {sheet} - {sex} - {event}")
            print(f"Total selected: {len(generator.selected_tables)}")
            print("\nCurrent selection:")
            for i, (s, sx, e, _) in enumerate(generator.selected_tables, 1):
                print(f"{i}. {s} - {sx} - {e}")

    def preview_data(b):
        sheet, sex, event = table_dropdown.value
        data = generator.preview_table_data(sheet, sex, event)

        # Sort the preview data too
        if 'TIME' in data.columns:
            def time_to_seconds(time_str):
                if pd.isna(time_str):
                    return float('inf')
                try:
                    time_str = str(time_str).strip()
                    if ':' in time_str:
                        parts = time_str.split(':')
                        minutes = float(parts[0])
                        seconds = float(parts[1])
                        return minutes * 60 + seconds
                    else:
                        return float(time_str)
                except (ValueError, AttributeError):
                    return float('inf')

            data = data.copy()
            data['time_seconds'] = data['TIME'].apply(time_to_seconds)
            data = data.sort_values('time_seconds')
            # Show the time_seconds for debugging
            print("Debug - time conversion (first 5):")
            for _, row in data.head().iterrows():
                print(f"  {row['TIME']} -> {row['time_seconds']}")
            data = data.drop('time_seconds', axis=1).reset_index(drop=True)

        with output:
            clear_output()
            print(f"Preview: {sheet} - {sex} - {event} (sorted by time)")
            print(f"Rows: {len(data)}")
            display(data)

    def generate_latex(b):
        generator.layout_config['per_row'] = per_row_slider.value
        generator.layout_config['per_page'] = per_page_slider.value

        latex_code = generator.generate_layout_latex(layout_dropdown.value)

        with output:
            clear_output()
            print(latex_code)

    def clear_selection(b):
        generator.selected_tables = []
        with output:
            clear_output()
            print("Selection cleared!")

    # Connect buttons
    add_button.on_click(add_table)
    preview_button.on_click(preview_data)
    generate_button.on_click(generate_latex)
    clear_button.on_click(clear_selection)

    # Layout
    table_controls = widgets.HBox([table_dropdown])
    action_buttons = widgets.HBox([add_button, preview_button, clear_button])
    layout_controls = widgets.VBox([
        widgets.Label("Layout Configuration:"),
        per_row_slider,
        per_page_slider,
        layout_dropdown,
        generate_button
    ])

    interface = widgets.VBox([
        widgets.Label("Swimming Table Generator"),
        table_controls,
        action_buttons,
        layout_controls,
        output
    ])

    return interface

# Create and display the interface
interface = create_table_interface()
display(interface)
# Out:
# VBox(children=(Label(value='Swimming Table Generator'), HBox(children=(Dropdown(description='Select Table:', o…
